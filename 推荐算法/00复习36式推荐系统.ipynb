# %% [markdown]
# # 概念片
# >EE[套索和利用]、冷启动、概率思维
#
# ## 个推
# - 公式
# - 信息过载
#
# ## 问题
# - 数据
#     - 评分数据
#     - 行为数据
# - 问题模式
#     - 冷启
#     - EE 探索利用
#     - 问题分析处理【安全问题】
#
# ## 思维模式
# - 目标思维
# - 不确定性思维
#     - 概率
#     - 大局、趋势
#     - EE
#
# # 内容推荐
# ## 用户画像
# - 定义
# - 关键因素
#     - 维度
#     - 量化
# - 构建方法
#     - 查户口
#     - 堆数据
#     - 黑盒子
#
# ## 从文本到用户画像
# - 文本开始
#     - 用户
#     - 物品
#     - 表达形式
# - 用户画像构建
#     - 步骤
#         - 1.非结构--》结构化
#         - 2.物品结构+用户结构融合
#     - 文本构建
#         - 关键词提取 TF-IDF,TextRank
#         - 实体识别 crf
#         - 内容分类  svm,fasttext
#         - 主题分类  聚类  LDA
#             - gensim
#             - PLDA
#         - 嵌入
#             -word2vec
#     - 算法
#         - TF-IDF,textrank
#         - crf
#         - fasttext
#         - gensim,PLDA
#         - word2vec
#     - 标签选择【分类问题】
#         - 思想方法
#             - 文档
#             - 类别
#             - 集合
#             - 提取
#         - 卡方检验
#             - 单独筛选一套标签
#         - 信息增益
#             - 全局标签
#
# ## 超越标签的推荐系统
# - 如何做好内容推荐
#     - 抓
#     - 洗
#     - 挖
#     - 算
# - 基于内容推荐的框架
#     - 内容源
#     - 内容分析和用户分析
#         - 内容挖掘分析
#         - 例子 快手
#             - 无
#             - 标题、描述
#             - 分析主题
#             - 实体识别
#             - 隐语义
#         - 内容库
#             - 分类模型
#             - 主体模型
#             - 主体识别
#             - 词嵌入
#     - 内容推荐算法
#         - 计算相似性 余弦相似度
#         - BM25F 【卡方类似】
#         - 模型
#             - 逻辑回归
#             - gbdt
#
# ## 近邻推荐
# - 基于用户的协同过滤
#     - 思想
#         - 用户聚类过程
#     - 原理
#         - 用户向量
#         - 求相似用户
#         - 物品打分
#     - 实战
#         - 矩阵构造
#             - csr,coo
#         - 相似度计算
#             - 降低计算复杂度
#                 - 对向量采样【dimsum】
#                 - 向量化计算 numpy
#             - 缓解性能代价
#                 - rm
#                 - 单机工具 KGraph，KGraphCHI
#         - 推荐计算
#             - OpenMP    多线程高效
#         - 一些改进
#             - 时间衰老
#             - 热门物品惩罚
#     - 应用场景
#        - 相似用户
#        - 基于用户的推荐结果
#
# ## 基于物品的协同过滤
# - 原理
#     - 物品关系矩阵
#         - 构建
#         - 推荐方式
#             - 一个物品关联的物品列表
#             - 看了又看
# - 优点
#     - 物品数小于用户数  物品之间的计算不会成为瓶颈
#     - 相似度比较静态
#     - 物品对应的消费则数量很大，计算物品间的相似度比用户间相似度好计算
# - 物品相似度计算
#     - 物品矩阵
#     - 改进
#         - 物品中心化 减去均值
#         - 用户中心化 减去均值
# - 推荐结果计算
#     - topK
#     - slopOne   实时更新
#
# ## 计算相似度的方法
# - 欧式距离
# - 余弦相似度
#     - 改进：取均值
# - 杰卡德
#     - 布尔向量
#     - 隐式反馈数据（行为数据）
# - 皮尔逊相关系数
#     - 变量的相关趋势
# - 问答
#     - 社交网络
#         - 标签
#         - 关键词
#         - 融合
#
# ## 为什么矩阵分解
# - svd算法
# - 增加偏置信息
# - 增加历史行为
# - 考虑时间因素
#
# ## FaceBook 好友推荐
# - 回顾矩阵分解
# - 交替最小二乘
# - 隐式反馈
#     - 负样本采样
# - 推荐计算
#
# ## 排序效果模型
# - 矩阵分解不足
# - 贝叶斯个性化推荐
#     - AUC
#     - 构建样本
#     - 目标函数
#     - 训练方法
#
# ## 应用其他算法
# - 排行榜体系
#     - 因素
#         - 时间
#         - 三种投票
#         - 好评的平均程度
#             - 电影评分例子
#             - 问题评分例子
# - 加权采样
#     - 热门排行榜
#
# ## 推荐系统架构
# - 经典的信息流推荐架构是什么样的
#     - 整体框架
#     - 数据模型
#         - 内容即Activity
#         - 关系即连接
#     - 内容发布
#     - 信息流排序
#     - 数据管道
# - Netflix个性化首页架构
#     - 架构的重要性
#     - 经典架构
#         - 数据流
#         - 在线层
#         - 离线层
#         - 近线层
#     - 简化架构
# - 推荐架构和搜索广告的关系
#     - 三种信息获取方式
#     - 三者对比
#     - 架构抽象
#         - 过滤候选
#         - 排序候选
#         - 个性化输出
#         - 三者协调
#
# ## 关键模块
# - 数据采集关键要素
#     - 日志和数据
#     - 数据采集
#         - 数据模型
#         - 怎么收集
#         - 质量监控
#         - 元素
#
# - 实时推荐
#     - 架构预览
#     - 实时数据
#     - 流计算
#     - 算法是实话
#     - 提高效率
# - 实验平台
#     - 数据驱动实验平台
#     - 重叠实验架构
#     - 统计效果
#     - 对比试验弊端
# - 存储选型和API设计
#     - 存储
#         - 列
#         - 键值存储
#         - 非数据库
#     - API
#         - 猜你喜欢
#         - 相关推荐
#         - 热门排行榜
#
#  ## 保证效果
#  - 测试
#     - 系统有多好
#         - 指标
#     - 好多久
#         - 个性化
#         - 基尼系数
#         - 多样性
#  - 攻防
#     - 攻
#         - 元素
#             - 目标物品
#             - 陪跑物品
#             - 助攻物品
#         - 分类
#             - 随机攻击
#             - 平均攻击
#             - 狡猾攻击
#                 - 热门攻击
#                 - 分段攻击
#     - 防
#         - 层级
#             - 平台层
#             - 数据层
#             - 算法层
#         - 改进
#             - 用户质量
#             - 用户权重限制
#
# ## 开源框架
# - 内容分析
#     - 主体模型
#         - LightLDA
#         - gensim
#         - plda
#         - hanpl
#     - 词嵌入
#         - fasttext
#         - tensorflow-work2vec
#     - 文本分类
#         - fasttext
# - 协同过滤矩阵分解
#     - knn
#     - svd
#     - als
#     - bpr
# - 模型融合
# - 其他
# - 整个推荐系统

# %% [markdown]
# ## 安全与风控
# > 黑产，色情交易，非法医美
#
# - 敏感词过滤，
# - 决策引擎，
# - 加盾，
# - APP加固
# ### 内容
# - 垃圾内容
#     - 平衡误杀率和ROI
#
# > 账号特征有数百个维度，例如注册时间，年龄，性别，发布时间，常用标签，ip地址，设备号（imac，imei，device id），手机号，性别，归属地，APP来源（华为市场，小米市场，APP Store），登录模式（APP，小程序，H5），手机型号，GPS地址，LBS区域，用户注册来源（自来水，A活动推广，市场投放转化，CPA），历史行为（点赞数，关注人），浏览行为
#
# >阿里有最全的电商黑产库，腾讯有最全的社交黑产库，网易有最全的游戏黑产库

# %% [markdown]
# ## 我的面试
# > 我是xx ,来自XXX,毕业于xxx
#
# > javaweb
#
# > 量化统计
#
# > 衣料+
# - 统计分析：次数，频次，时长，转化，留存，sku，人均消费，客单价，同比，环比
# - itembase cf,userbase cf
#
# >华南运营中心营销大数据平台
# - 主要功能
#     - 1、风险防控
#     - 2、精准营销
#     - 3、集群洞察
#     - 4、智慧运营
#     - 5、大数据云
#     - 责任描述：
#     - 精准营销模块大数据开发
#     - 1、数据进行清洗，特征数据提取。
#     - 2、数据挖掘，挖掘用户标签。
#     - 3、数据爬取，爬取相关行业数据。
#     - 4、开发用户画像
# - 项目介绍：精准营销通过大数据挖掘精准用户，然后通过电销系统触达用户
# - 上线效果：接听率提高 10-20%，转化率 2-4%
# - 特征处理
#
# - 用户画像【静态属性【性别，年龄，籍贯，位置等】，通话，位置，url,app,终端，文本，关键词，短信，终端】，用户标签，行业标签，终端标签，文本挖掘
#     - 关键词embedding  content embedding 加权和衰减
# - 数据效果：接听率提高 10-20%，转化率 2-4%
#
# >中国电信华南运营中心大数据平台主要功能
#
#
# >报告智能纠错系统
# - 错别字 识别率 80-95%
# - 纠错正确率 70-85%
# - 效率提高 100%
# - pycorrect,行业报告作为语料
#
# >合成作战平台预警行为分析挖掘
# - 嫌疑预警行为挖掘
#     - 文本分析
#     - 位置分析
# - 人脸搜索
#     - 召回和精确率，跟图片像素，阀值有关系 正常 召回达到 80%以上，精确80%以上
#     - dlib ,cnn
#     - face_recognition
# - 关联分析
#     - 伴随分析
#     - 碰撞分析
#
# >awifi 资讯推荐系统
# - 项目背景
#     - 30w台ap,月采集日志15亿,活跃ip有2000w
#     - 传统的类目内容资讯无法满足现在的注意力，导致点击率和转化率地下
#     - 打造推荐系统
# - 效果
#     - 点击率提高150-250%
#     - 转化率 50-150%
#     - 停留时长增加 200%
# - 我的职责
#     - 项目算法负责人
#     - 项目从0-1的过程，项目复盘
#         - 项目冷启动 新用户新内容
#             - 用户标签画像打造 embedding
#                 - url属性
#                     - 关键词
#                 - 终端属性
#                     - 机型相关
#                 - 位置属性
#                     - ap位置
#                     - 归宿地
#                     - 场所
#                 - 网络内容属性
#                     - 社交平台
#                     - 内容平台 聚类 分类
#                 - 个性化标签属性
#             - 内容标签画像打造 embedding
#                 - 内容分类 LDA，gensim，fasttext，ifidf
#                 - 内容聚类 词嵌入
#             - bandit算法
#                 - 内容topic随机发,使用汤普森采样或者ucb
#             - userbase，articlebase,contentbase
#                 - userbaseCF
#                     - 行为日志
#                         - 点击，收藏，评论
#                 - articlebaseCF
#                     - 行为日志
#                         - 点击，收藏，评论
#                 - contentbaseCF
#                 - 矩阵分解 svd
#             - 排序算法
#                 - gbdt+lr
#                 - bpr
#                 - deepFm
#             - 实时架构
#                 - 离线层
#                     - 定时计算更新模型
#                     - 特征数据更新
#                 - 在线层
#                     - 实时更新补充用户标签，用户画像，文章标签
#             - 测试
#                 - 分配流量
#                 - 监控效果【参数，模型】
#             - 设计排序算法，建立、测试、调优排序模型
#             - 关于荔枝
#                 - 加入rnn
